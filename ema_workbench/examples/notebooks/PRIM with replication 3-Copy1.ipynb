# %%
from ema_workbench import ema_logging, load_results
import numpy as np
import matplotlib.pyplot as plt
from ema_workbench.analysis.plotting import envelopes, lines
from ema_workbench.analysis.plotting_util import KDE
from ema_workbench.analysis import prim

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
n = 100
fn = r'../data/{} runs.tar.gz'.format(n)
experiments, outcomes = load_results(fn)
# Out:
# [MainProcess/INFO] results loaded succesfully from D:\Workspace\EMAworkbench\ema_workbench\examples\data\100 runs.tar.gz

# %%
print(experiments.shape)
print(outcomes['sheep'].shape)
# Out:
# (100L,)
# (100L, 10L, 101L)

# %%
fig, ax = plt.subplots(1)


ax.plot(outcomes['sheep'][:,0,:].T)
ax.set_ylabel('Count')

fig.set_size_inches(6,6)
plt.show()

# %%
ooi_name = "sheep"
outcome = outcomes[ooi_name]
print ooi.shape
ooi = np.reshape(ooi, (ooi.shape[0]*ooi.shape[1], ooi.shape[2]))
temp_outcomes = {ooi_name: ooi}

print ooi.shape
# Out:
# (100L,)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-5eebc75243b5> in <module>()
#       2 outcome = outcomes[ooi_name]
#       3 print ooi.shape
# ----> 4 ooi = np.reshape(ooi, (ooi.shape[0]*ooi.shape[1], ooi.shape[2]))
#       5 temp_outcomes = {ooi_name: ooi}
#       6
#
# IndexError: tuple index out of range

# %%
fig, axes = envelopes(results, group_by='policy', density=KDE, fill=True)

# we can access each of the axes and make changes
for key, value in axes.iteritems():
    # the key is the name of the outcome for the normal plot
    # and the name plus '_density' for the endstate distribution
    if key.endswith('_density'):
        value.set_xscale('log')

plt.show()
# Out:
# [MainProcess/WARNING] value error when plotting for None
# (10L, 101L)
# (10L, 101L)
# (10L, 101L)
# (10L,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-58ad261eb146> in <module>()
# ----> 1 fig, axes = envelopes(results, group_by='policy', density=KDE, fill=True)
#       2
#       3 # we can access each of the axes and make changes
#       4 for key, value in axes.iteritems():
#       5     # the key is the name of the outcome for the normal plot
#
# D:\Workspace\EMAworkbench\ema_workbench\analysis\plotting.pyc in envelopes(results, outcomes_to_show, group_by, grouping_specifiers, density, fill, legend, titles, ylabels, log)
#     136         if group_by:
#     137             group_by_envelopes(outcomes,outcome_to_plot, time, density,
# --> 138                                ax, ax_d, fill, grouping_labels, log)
#     139         else:
#     140             single_envelope(outcomes, outcome_to_plot, time, density,
#
# D:\Workspace\EMAworkbench\ema_workbench\analysis\plotting.pyc in group_by_envelopes(outcomes, outcome_to_plot, time, density, ax, ax_d, fill, group_labels, log)
#     206         value = value[outcome_to_plot]
#     207         try:
# --> 208             plot_envelope(ax, j, time, value,fill)
#     209         except ValueError:
#     210             warning("value error when plotting for %s" % (key))
#
# D:\Workspace\EMAworkbench\ema_workbench\analysis\plotting_util.pyc in plot_envelope(ax, j, time, value, fill)
#      99                         maximum,
#     100                         facecolor=color,
# --> 101                         alpha=0.3,
#     102                         )
#     103     else:
#
# C:\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1816                     warnings.warn(msg % (label_namer, func.__name__),
#    1817                                   RuntimeWarning, stacklevel=2)
# -> 1818             return func(ax, *args, **kwargs)
#    1819         pre_doc = inner.__doc__
#    1820         if pre_doc is None:
#
# C:\Anaconda2\lib\site-packages\matplotlib\axes\_axes.pyc in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    4599
#    4600         if not (x.shape == y1.shape == y2.shape == where.shape):
# -> 4601             raise ValueError("Argument dimensions are incompatible")
#    4602
#    4603         mask = reduce(ma.mask_or, [ma.getmask(a) for a in (x, y1, y2)])
#
# ValueError: Argument dimensions are incompatible

# %%
import scipy as sp

# %%
ooi_name = "level_of_achievability"
def classify(data):
    data = data[ooi_name]
    data = data[:,-1]
    classes = np.zeros(data.shape)
    classes[data>0.2] = 1
    return classes

#prim_obj = prim.Prim((experiments, temp_outcomes), classify, threshold=1)
prim_obj = prim.setup_prim(results, classify, mass_min=0.05, threshold=0.75)

# %%
box1 = prim_obj.find_box()
# Out:
# [MainProcess/INFO] 2000 points remaining, containing 80 cases of interest
# [MainProcess/INFO] box does not meet threshold criteria, value is 0.509615384615, returning dump box

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# C:\Anaconda2\lib\site-packages\IPython\core\formatters.pyc in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# C:\Anaconda2\lib\site-packages\IPython\core\pylabtools.pyc in <lambda>(fig)
#     238
#     239     if 'png' in formats:
# --> 240         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     241     if 'retina' in formats or 'png2x' in formats:
#     242         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Anaconda2\lib\site-packages\IPython\core\pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     122
#     123     bytes_io = BytesIO()
# --> 124     fig.canvas.print_figure(bytes_io, **kw)
#     125     data = bytes_io.getvalue()
#     126     if fmt == 'svg':
#
# C:\Anaconda2\lib\site-packages\matplotlib\backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2178                     orientation=orientation,
#    2179                     dryrun=True,
# -> 2180                     **kwargs)
#    2181                 renderer = self.figure._cachedRenderer
#    2182                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# C:\Anaconda2\lib\site-packages\matplotlib\backends\backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     525
#     526     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 527         FigureCanvasAgg.draw(self)
#     528         renderer = self.get_renderer()
#     529         original_dpi = renderer.dpi
#
# C:\Anaconda2\lib\site-packages\matplotlib\backends\backend_agg.pyc in draw(self)
#     472
#     473         try:
# --> 474             self.figure.draw(self.renderer)
#     475         finally:
#     476             RendererAgg.lock.release()
#
# C:\Anaconda2\lib\site-packages\matplotlib\artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# C:\Anaconda2\lib\site-packages\matplotlib\figure.pyc in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# C:\Anaconda2\lib\site-packages\matplotlib\artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# C:\Anaconda2\lib\site-packages\matplotlib\axes\_base.pyc in draw(self, renderer, inframe)
#    2317
#    2318         for zorder, a in dsu:
# -> 2319             a.draw(renderer)
#    2320
#    2321         renderer.close_group('axes')
#
# C:\Anaconda2\lib\site-packages\matplotlib\artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# C:\Anaconda2\lib\site-packages\matplotlib\collections.pyc in draw(self, renderer)
#     813     def draw(self, renderer):
#     814         self.set_sizes(self._sizes, self.figure.dpi)
# --> 815         Collection.draw(self, renderer)
#     816
#     817
#
# C:\Anaconda2\lib\site-packages\matplotlib\artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      60     def draw_wrapper(artist, renderer, *args, **kwargs):
#      61         before(artist, renderer)
# ---> 62         draw(artist, renderer, *args, **kwargs)
#      63         after(artist, renderer)
#      64
#
# C:\Anaconda2\lib\site-packages\matplotlib\collections.pyc in draw(self, renderer)
#     261         renderer.open_group(self.__class__.__name__, self.get_gid())
#     262
# --> 263         self.update_scalarmappable()
#     264
#     265         transform, transOffset, offsets, paths = self._prepare_points()
#
# C:\Anaconda2\lib\site-packages\matplotlib\collections.pyc in update_scalarmappable(self)
#     711             return
#     712         if self._is_filled:
# --> 713             self._facecolors = self.to_rgba(self._A, self._alpha)
#     714         elif self._is_stroked:
#     715             self._edgecolors = self.to_rgba(self._A, self._alpha)
#
# C:\Anaconda2\lib\site-packages\matplotlib\cm.pyc in to_rgba(self, x, alpha, bytes)
#     259         # This is the normal case, mapping a scalar array:
#     260         x = ma.asarray(x)
# --> 261         x = self.norm(x)
#     262         x = self.cmap(x, alpha=alpha, bytes=bytes)
#     263         return x
#
# C:\Anaconda2\lib\site-packages\matplotlib\colors.pyc in __call__(self, value, clip)
#    1312             iret[xx >= b] = i
#    1313         if self._interp:
# -> 1314             scalefac = float(self.Ncmap - 1) / (self.N - 2)
#    1315             iret = (iret * scalefac).astype(np.int16)
#    1316         iret[xx < self.vmin] = -1
#
# ZeroDivisionError: float division by zero

# %%
box1.write_ppt_to_stdout()
# Out:
#    coverage  density  mass  mean  res dim
# 0       1.0     0.04   1.0  0.04      0.0

# %%
box1.inspect(0)
box1.inspect(1)
box1.inspect(2)
box1.inspect(3)
box1.inspect(4)
box1.inspect(5)
# Out:
# coverage    1.00
# density     0.04
# mass        1.00
# mean        0.04
# res dim     0.00
# Name: 0, dtype: float64
#
# Empty DataFrame
# Columns: [(box 0, min), (box 0, max), (box 0, qp values)]
# Index: []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-29898d5970fd> in <module>()
#       1 box1.inspect(0)
# ----> 2 box1.inspect(1)
#       3 box1.inspect(2)
#       4 box1.inspect(3)
#       5 box1.inspect(4)
#
# D:\Workspace\EMAworkbench\ema_workbench\analysis\prim.pyc in inspect(self, i, style, **kwargs)
#     275             i = self._cur_box
#     276
# --> 277         stats = self.peeling_trajectory.iloc[i].to_dict()
#     278         stats['restricted_dim'] = stats['res dim']
#     279
#
# C:\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in __getitem__(self, key)
#    1294             return self._getitem_tuple(key)
#    1295         else:
# -> 1296             return self._getitem_axis(key, axis=0)
#    1297
#    1298     def _getitem_axis(self, key, axis=0):
#
# C:\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in _getitem_axis(self, key, axis)
#    1610
#    1611                 # validate the location
# -> 1612                 self._is_valid_integer(key, axis)
#    1613
#    1614             return self._get_loc(key, axis=axis)
#
# C:\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in _is_valid_integer(self, key, axis)
#    1524         l = len(ax)
#    1525         if key >= l or key < -l:
# -> 1526             raise IndexError("single positional indexer is out-of-bounds")
#    1527         return True
#    1528
#
# IndexError: single positional indexer is out-of-bounds
